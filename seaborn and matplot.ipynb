# %% [markdown]
# ### matplotlib : it is used to visuals the data or create some graph  on the basis of our dataset.
#
# installation :
# !pip install matplotlib
#
# pip install matplotlib

# %% [markdown]
# call out
#
# without
#
# import matplotlib.pyplot
#
# import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4,5])
y = np.array([1,4,9,16,25])

plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'o')
plt.show()

# %%
plt.plot(y)
plt.show()

# %%
plt.plot(y,'H')
plt.show()

# %%
markers :
1. circle = 'o'
2. str = '*'
point = .
x  = x
plus ='+'
.....

# %%
plt.plot(y,marker = 'H')
plt.show()

# %%
plt.plot(y,'H:r') # H = marker r :color
plt.show()

# %%
plt.plot(y,ls=':',ms = 20,marker='H',color='g',mec='b') # H = marker r :color
plt.show()  # ls; line style mskrer = point # mec marker edge color

# %%
plt.xlabel(" Numbers ")
plt.ylabel(" Square of the number ")
plt.title("Number vs square")

plt.grid()

plt.plot(x,y,marker='o')
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.bar(x,y)
plt.grid()
plt.legend()
plt.plot()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16596\1611188482.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# []

# %% [markdown]
# x = [1,2,3,4,5]
# y = [1,4,9,16,25]
# plt.pie(y,labels=x)
# plt.legend()
# plt.show()

# %% [markdown]
# ### Seaborn :  it is a visualizing library in python built using matplotlib

# %%
pip install seaborn : for terminal 
# !pip install seaborn

# %%
import seaborn

# %%
import seaborn as sns

# %%
sns.distplot([1,2,3,4,5,6,7,8])
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16596\2815196094.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([1,2,3,4,5,6,7,8])

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]

sns.barplot(data=y)
plt.show()

# %%
sns.countplot(data=x)
plt.show()

# %%
data = sns.get_dataset_names()

# %%
data
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('iris')

# %%
df.head(10) # upper 10 rows
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.barplot(x ='species',y = 'sepal_length' , data = df)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
a = sns.countplot(x ='species' , data = df)

# %%
sns.boxplot(x='species',y = 'sepal_length',data=df)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.violinplot(x='species',y = 'sepal_length',data=df)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>
